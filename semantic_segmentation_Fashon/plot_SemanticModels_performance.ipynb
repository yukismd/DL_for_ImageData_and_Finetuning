# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !ls
# Out:
# Experiments_SemanticSegmentation.xlsx plot_SemanticModels_performance.ipynb

# %%
df = pd.read_excel('Experiments_SemanticSegmentation.xlsx', sheet_name='ALL')
df.shape
# Out:
# /opt/anaconda3/envs/ML/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /opt/anaconda3/envs/ML/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# (63, 11)

# %%
df.head()
# Out:
#                                                 name Architecture  \
# 0  seg_unet_backbone_tu-regnetz_d8_learning_rate_...        U-Net
# 1  seg_unet_backbone_tu-regnetz_d8_learning_rate_...        U-Net
# 2  seg_unet_backbone_tu-regnetz_d8_learning_rate_...        U-Net
# 3    seg_unet_backbone_resnet50_learning_rate_0.0001        U-Net
# 4    seg_unet_backbone_resnet50_learning_rate_0.0003        U-Net
#
#         Backbone  Backbone Param Size (M)  Learning Rate  Batch Size  Epochs  \
# 0  tu-regnetz_d8                    23.37         0.0001          16       5
# 1  tu-regnetz_d8                    23.37         0.0003          16       5
# 2  tu-regnetz_d8                    23.37         0.0010          16       5
# 3       resnet50                    23.00         0.0001          32       5
# 4       resnet50                    23.00         0.0003          32       5
#
#    Image Size (H&W)    Status  Validation IoU   Runtime
# ...

# %%
# Create the scatter plot using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Architecture", y="Validation IoU", hue="Backbone", palette="Set1", s=100)

# Improve plot aesthetics
plt.title("Validation IoU vs Architecture, colored by Backbone")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
