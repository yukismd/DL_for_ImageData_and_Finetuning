# %%
# !ls
# Out:
# Untitled.ipynb           test_predictions.csv     test_raw_predictions.pkl

# %%
import pandas as pd

# %%
d = pd.read_pickle('test_raw_predictions.pkl')
d
# Out:
# {'embeddings': array([[-1.0080061 ,  6.626627  ,  5.498792  , ..., -2.7803657 ,
#           2.1900501 , -0.31037804],
#         [ 1.8076658 , -0.0837328 , -0.06001232, ..., -0.32882294,
#          -0.02725692,  0.61945534],
#         [-0.07383408, -0.21913807, -0.28415924, ...,  1.2176586 ,
#           0.2574096 , -0.07997387],
#         ...,
#         [ 2.1409788 , -0.21087517, -0.14022194, ...,  0.27084935,
#           0.20710701, -0.49243137],
#         [ 0.54106987,  1.432435  ,  1.1813226 , ...,  1.1039402 ,
#           0.0384907 ,  0.29449114],
#         [-0.05990129, -0.35038307, -0.0343996 , ..., -0.08892709,
#          -0.18286857, -0.08638632]], dtype=float32),
#  'cosine_similarities': array([[1.        , 0.9891212 , 0.9826696 , ..., 0.46600664, 0.46503562,
#          0.46327227],
#         [1.0000001 , 0.84561753, 0.7217287 , ..., 0.4757403 , 0.4749069 ,
#          0.47400093],
#         [1.        , 0.8016686 , 0.78007174, ..., 0.5513512 , 0.5423597 ,
# ...

# %%
d.keys()
# Out:
# dict_keys(['embeddings', 'cosine_similarities', 'similar_images', 'image_id'])
