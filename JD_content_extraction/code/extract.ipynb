# %% [markdown]
# # JDからの情報抽出

# %% [markdown]
# Building Effective Agents Cookbook: https://github.com/anthropics/anthropic-cookbook/tree/main/patterns/agents
# Evaluator-Optimizer Workflow: https://github.com/anthropics/anthropic-cookbook/blob/main/patterns/agents/evaluator_optimizer.ipynb

# %%
from dotenv import load_dotenv
import os
import json
import re

import pandas as pd
import pdfplumber

from h2ogpte import H2OGPTE

# %%
jd_path = '../JDs/'
pdf_files = [file for file in os.listdir(jd_path) if file.endswith(".pdf")]
pdf_files
# Out:
# ['Digital BCG - Data Scientist.pdf',
#  'Robust Intelligence - Machine Learning Engineer.pdf',
#  'Eli Lilly - Data Scientist, Global Report.pdf',
#  'OpenAI - Principal Solutions Engineer – Japan.pdf',
#  'Money Forward - AI Soultions Engineer.pdf',
#  'AWS - Sr. Generative AI Specialist, Generative AI Innovation Center.pdf',
#  'Senior Data Scientist @ Dataiku.pdf']

# %%
load_dotenv(dotenv_path='.env')
heogpte_key = os.getenv('h2oGpteKey_AgentWorkflow')
if heogpte_key: print('key is set.')
# Out:
# key is set.

# %%
client = H2OGPTE(
    address='https://h2ogpte.dev.h2o.ai',
    api_key=heogpte_key,   # Collection Key
)

chat_session_id = client.create_chat_session_on_default_collection()

client, chat_session_id
# Out:
# (<h2ogpte.h2ogpte.H2OGPTE at 0x10a892770>,
#  '00d2d44e-d852-4400-abfc-27df2ba9d0c7')

# %%
# 利用可能なLLM
#client.get_llm_names()

# %%
def llm_call(prompt: str, system_prompt: str = "あなたは優秀なAIアシスタントです。指示に的確に従います。", model='gpt-4o-mini') -> str:
    with client.connect(chat_session_id) as session:
        reply = session.query(
            message=prompt,
            #system_prompt=system_prompt,
            llm=model,
            rag_config = {"rag_type": "llm_only"},
            timeout=60,
        )
        return reply.content

def extract_xml(text: str, tag: str) -> str:
    match = re.search(f'<{tag}>(.*?)</{tag}>', text, re.DOTALL)
    return match.group(1) if match else ""

# %%
def generate(prompt: str, task: str, context: str = "") -> tuple[str, str]:
    """Generate and improve a solution based on feedback."""
    full_prompt = f"{prompt}\n{context}\nTask: {task}" if context else f"{prompt}\nTask: {task}"
    #print('generate full_prompt >>>>>>>>>>>>>>>>>', full_prompt, '<<<<<<<<<<<<<<<<<<< generate full_prompt')
    response = llm_call(full_prompt)
    thoughts = extract_xml(response, "thoughts")
    result = extract_xml(response, "response")
    
    print("\n=== GENERATION START ===")
    print(f"Thoughts:\n{thoughts}\n")
    print(f"Generated:\n{result}")
    print("=== GENERATION END ===\n")
    
    return thoughts, result

def evaluate(prompt: str, content: str, task: str) -> tuple[str, str]:
    """Evaluate if a solution meets requirements."""
    full_prompt = f"{prompt}\nOriginal task: {task}\nContent to evaluate: {content}"
    #print('evaluate full_prompt >>>>>>>>>>>>>>>>>', full_prompt, '<<<<<<<<<<<<<<<<<<< evaluate full_prompt')
    response = llm_call(full_prompt)
    evaluation = extract_xml(response, "evaluation")
    feedback = extract_xml(response, "feedback")
    
    print("=== EVALUATION START ===")
    print(f"Status: {evaluation}")
    print(f"Feedback: {feedback}")
    print("=== EVALUATION END ===\n")
    
    return evaluation, feedback

def loop(task: str, evaluator_prompt: str, generator_prompt: str) -> tuple[str, list[dict]]:
    """Keep generating and evaluating until requirements are met."""
    memory = []
    chain_of_thought = []
    
    thoughts, result = generate(generator_prompt, task)
    memory.append(result)
    chain_of_thought.append({"thoughts": thoughts, "result": result})
    
    while True:
        evaluation, feedback = evaluate(evaluator_prompt, result, task)
        if evaluation == "PASS":
            return result, chain_of_thought
            
        context = "\n".join([
            "Previous attempts:",
            *[f"- {m}" for m in memory],
            f"\nFeedback: {feedback}"
        ])
        
        thoughts, result = generate(generator_prompt, task, context)
        memory.append(result)
        chain_of_thought.append({"thoughts": thoughts, "result": result})

# %%
evaluator_prompt = """
与えられたテキストを以下2つの基準で判定してください。
1. 「会社名」「ポジション名」「必要な学歴」「必要な経験年数」「必要な言語スキル」「必要なテクニカルスキル」の6つ全ての項目が抽出されているか。なお「JDには記載なし」と出力されているものは正確に抽出されていると判断して問題ないです。
2.  抽出された情報はJSON形式となっているか。

タスクの解決を試みることなく、評価のみを行ってください。
すべての基準が満たされ、改善のための提案がない場合は、"PASS"のみを出力してください。
次の形式で簡潔に評価を出力してください。

<evaluation>PASS, NEEDS_IMPROVEMENT, or FAIL</evaluation>
<feedback>
改善が必要な理由。
</feedback>
"""

generator_prompt = """
目標は、<user input>に基づいてタスクを完了することです。
フィードバックを受け取った場合は、それを考慮して回答を改善する必要があります。

次の形式で簡潔に回答を出力してください。

<thoughts>
タスクとフィードバックに対する理解、および改善の計画。
</thoughts>

<response>
{
    "会社名":"回答",
    "ポジション名:"回答",
    "必要な学歴":"回答",
    "必要な経験年数":"回答",
    "必要な言語スキル":"回答",
    "必要なテクニカルスキル":"回答"
}
</response>
"""

# %%
reply_results = []

for pdf in pdf_files:
    print('START >>>>>>>>>> ', pdf)
    file_path = jd_path+pdf

    with pdfplumber.open(file_path) as pdf:
        text = "\n".join([page.extract_text() for page in pdf.pages if page.extract_text()])
    #print(text)

    task = """
    以下のJob Descriptionから、「会社名」「ポジション名」「必要な学歴」「必要な経験年数」「必要な言語スキル」「必要なテクニカルスキル」の6つを抽出してください。
    Job Description内に情報がない場合は、'JDには記載なし'と出力してください。
    
    # Job Description
    {}
    """.format(text)
    #print(task)

    reply = loop(task, evaluator_prompt, generator_prompt)
    reply_results.append(reply)

len(reply_results)
# Out:
# START >>>>>>>>>>  Digital BCG - Data Scientist.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。
#
#
# Generated:
#
# {
#     "会社名": "Digital BCG",
#     "ポジション名": "Data Scientist",
#     "必要な学歴": "Master's degree in a related field",
#     "必要な経験年数": "3+ years of work experience in data analytics",
#     "必要な言語スキル": "English proficiency (daily conversation level or higher)",
#     "必要なテクニカルスキル": "Coding skills in Python, R; Analysis experience using machine learning"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  Robust Intelligence - Machine Learning Engineer.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。
#
#
# Generated:
#
# {
#     "会社名": "Robust Intelligence",
#     "ポジション名": "Machine Learning Engineer",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "At least three years of professional experience with machine learning, ML operations, data science, or a related field",
#     "必要な言語スキル": "Native level fluency in spoken and written Japanese; Business fluency in spoken and written English",
#     "必要なテクニカルスキル": "Knowledge and experience of Python; Familiarity with advanced machine learning methods; Experience with tooling and platforms in the ML ecosystem"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  Eli Lilly - Data Scientist, Global Report.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。
#
#
# Generated:
#
# {
#     "会社名": "Eli Lilly Japan",
#     "ポジション名": "Data Scientist – OUS Commercial Analytics",
#     "必要な学歴": "M.S. or higher in Statistics, Econometrics, Operations Research, Computer Science, Engineering, Mathematics or closely related field",
#     "必要な経験年数": "JDには記載なし",
#     "必要な言語スキル": "Business level proficiency in English; Business level proficiency in Japanese is preferable",
#     "必要なテクニカルスキル": "Deep and broad knowledge of statistical modeling and data mining methods; Proficiency with relevant programming languages (such as R, Python, SQL, SAS, Java, C++, etc...)"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  OpenAI - Principal Solutions Engineer – Japan.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。
#
#
# Generated:
#
# {
#     "会社名": "OpenAI",
#     "ポジション名": "Principal Solutions Engineer – Japan",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "7+ years of experience in a Solutions Engineer (or similar) role",
#     "必要な言語スキル": "JDには記載なし",
#     "必要なテクニカルスキル": "Thorough understanding and knowledge of IT security principles and customer requirements for similar technical B2B SaaS products"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: NEEDS_IMPROVEMENT
# Feedback:
# === EVALUATION END ===
#
#
# === GENERATION START ===
# Thoughts:
#
# フィードバックを受けて、必要な言語スキルを正確に抽出することが重要であると理解しました。Job Descriptionには「Business level proficiency in English is a must; Business level proficiency in Japanese is preferable」という情報が含まれているため、これを反映させる必要があります。次回は、すべての項目を漏れなく抽出することを計画します。
#
#
# Generated:
#
# {
#     "会社名": "OpenAI",
#     "ポジション名": "Principal Solutions Engineer – Japan",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "7+ years of experience in a Solutions Engineer (or similar) role",
#     "必要な言語スキル": "Business level proficiency in English; Business level proficiency in Japanese is preferable",
#     "必要なテクニカルスキル": "Thorough understanding and knowledge of IT security principles and customer requirements for similar technical B2B SaaS products"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  Money Forward - AI Soultions Engineer.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。今回は、必要なスキルや経験を漏れなく抽出することを目指します。
#
#
# Generated:
#
# {
#     "会社名": "Money Forward",
#     "ポジション名": "JDには記載なし",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "Experience in practical application of AI/machine learning (from problem definition to AI solution selection, model review/development, application to services)",
#     "必要な言語スキル": "Basic business level English skills (equivalent to TOEIC 700 or above)",
#     "必要なテクニカルスキル": "Experience and understanding of software development; Basic knowledge of mathematics and statistics; Experience with data analysis and visualization using Python; Experience using cloud services such as AWS/GCP/Azure"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: NEEDS_IMPROVEMENT
# Feedback:
# === EVALUATION END ===
#
#
# === GENERATION START ===
# Thoughts:
#
# フィードバックを受けて、ポジション名と必要な学歴を正確に抽出することが重要であると理解しました。Job Descriptionにはポジション名が明示されていないため、これを反映させる必要があります。また、必要な学歴に関する情報も明記されていないため、正確に抽出する必要があります。次回は、これらの情報を漏れなく抽出することを計画します。
#
#
# Generated:
#
# {
#     "会社名": "Money Forward",
#     "ポジション名": "JDには記載なし",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "Experience in practical application of AI/machine learning (from problem definition to AI solution selection, model review/development, application to services)",
#     "必要な言語スキル": "Basic business level English skills (equivalent to TOEIC 700 or above)",
#     "必要なテクニカルスキル": "Experience and understanding of software development; Basic knowledge of mathematics and statistics; Experience with data analysis and visualization using Python; Experience using cloud services such as AWS/GCP/Azure"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: NEEDS_IMPROVEMENT
# Feedback:
# === EVALUATION END ===
#
#
# === GENERATION START ===
# Thoughts:
#
# フィードバックを受けて、ポジション名と必要な学歴を正確に抽出することが重要であると理解しました。Job Descriptionにはポジション名が明示されていないため、これを反映させる必要があります。また、必要な学歴に関する情報も明記されていないため、正確に抽出する必要があります。次回は、これらの情報を漏れなく抽出することを計画します。
#
#
# Generated:
#
# {
#     "会社名": "Money Forward",
#     "ポジション名": "AI/Machine Learning Engineer",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "Experience in practical application of AI/machine learning (from problem definition to AI solution selection, model review/development, application to services)",
#     "必要な言語スキル": "Basic business level English skills (equivalent to TOEIC 700 or above)",
#     "必要なテクニカルスキル": "Experience and understanding of software development; Basic knowledge of mathematics and statistics; Experience with data analysis and visualization using Python; Experience using cloud services such as AWS/GCP/Azure"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  AWS - Sr. Generative AI Specialist, Generative AI Innovation Center.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。今回は、すべての項目を漏れなく抽出することを目指します。
#
#
# Generated:
#
# {
#     "会社名": "Amazon Web Services Japan GK",
#     "ポジション名": "Sr. Generative AI Specialist",
#     "必要な学歴": "Bachelor's degree in computer science or equivalent",
#     "必要な経験年数": "5+ years of relevant working experience",
#     "必要な言語スキル": "JDには記載なし",
#     "必要なテクニカルスキル": "Experience with machine learning fundamentals; working knowledge of Python; experience with deep learning frameworks such as Pytorch, TensorFlow, JAX or MXNet"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
#
# START >>>>>>>>>>  Senior Data Scientist @ Dataiku.pdf
#
# === GENERATION START ===
# Thoughts:
#
# Job Descriptionから必要な情報を抽出するタスクを理解しました。特に、必要な学歴や経験年数、スキルに関する情報を正確に把握することが重要です。フィードバックを受けた場合には、情報の正確性や明確さを向上させるために、より詳細な分析を行う計画です。今回は、すべての項目を漏れなく抽出することを目指します。
#
#
# Generated:
#
# {
#     "会社名": "Dataiku",
#     "ポジション名": "Senior Data Scientist",
#     "必要な学歴": "JDには記載なし",
#     "必要な経験年数": "8 years + of experience in advanced analytics, data science projects, or consulting",
#     "必要な言語スキル": "Japanese - native; highly proficient in spoken and written English",
#     "必要なテクニカルスキル": "Over 5 years of experience with Python and SQL; Over 5 years of experience with building ML models and using ML tools (e.g. sklearn)"
# }
#
# === GENERATION END ===
#
# === EVALUATION START ===
# Status: PASS
# Feedback:
# === EVALUATION END ===
# 7

# %%
len(reply_results)
# Out:
# 7

# %%
l0 = []
l1 = []
l2 = []
l3 = []
l4 = []
l5 = []

for r in reply_results:
    jsn = json.loads(r[0])
    print(jsn)
    l0.append(jsn['会社名'])
    l1.append(jsn['ポジション名'])
    l2.append(jsn['必要な学歴'])
    l3.append(jsn['必要な経験年数'])
    l4.append(jsn['必要な言語スキル'])
    l5.append(jsn['必要なテクニカルスキル'])
# Out:
# {'会社名': 'Digital BCG', 'ポジション名': 'Data Scientist', '必要な学歴': "Master's degree in a related field", '必要な経験年数': '3+ years of work experience in data analytics', '必要な言語スキル': 'English proficiency (daily conversation level or higher)', '必要なテクニカルスキル': 'Coding skills in Python, R; Analysis experience using machine learning'}
# {'会社名': 'Robust Intelligence', 'ポジション名': 'Machine Learning Engineer', '必要な学歴': 'JDには記載なし', '必要な経験年数': 'At least three years of professional experience with machine learning, ML operations, data science, or a related field', '必要な言語スキル': 'Native level fluency in spoken and written Japanese; Business fluency in spoken and written English', '必要なテクニカルスキル': 'Knowledge and experience of Python; Familiarity with advanced machine learning methods; Experience with tooling and platforms in the ML ecosystem'}
# {'会社名': 'Eli Lilly Japan', 'ポジション名': 'Data Scientist – OUS Commercial Analytics', '必要な学歴': 'M.S. or higher in Statistics, Econometrics, Operations Research, Computer Science, Engineering, Mathematics or closely related field', '必要な経験年数': 'JDには記載なし', '必要な言語スキル': 'Business level proficiency in English; Business level proficiency in Japanese is preferable', '必要なテクニカルスキル': 'Deep and broad knowledge of statistical modeling and data mining methods; Proficiency with relevant programming languages (such as R, Python, SQL, SAS, Java, C++, etc...)'}
# {'会社名': 'OpenAI', 'ポジション名': 'Principal Solutions Engineer – Japan', '必要な学歴': 'JDには記載なし', '必要な経験年数': '7+ years of experience in a Solutions Engineer (or similar) role', '必要な言語スキル': 'Business level proficiency in English; Business level proficiency in Japanese is preferable', '必要なテクニカルスキル': 'Thorough understanding and knowledge of IT security principles and customer requirements for similar technical B2B SaaS products'}
# {'会社名': 'Money Forward', 'ポジション名': 'AI/Machine Learning Engineer', '必要な学歴': 'JDには記載なし', '必要な経験年数': 'Experience in practical application of AI/machine learning (from problem definition to AI solution selection, model review/development, application to services)', '必要な言語スキル': 'Basic business level English skills (equivalent to TOEIC 700 or above)', '必要なテクニカルスキル': 'Experience and understanding of software development; Basic knowledge of mathematics and statistics; Experience with data analysis and visualization using Python; Experience using cloud services such as AWS/GCP/Azure'}
# {'会社名': 'Amazon Web Services Japan GK', 'ポジション名': 'Sr. Generative AI Specialist', '必要な学歴': "Bachelor's degree in computer science or equivalent", '必要な経験年数': '5+ years of relevant working experience', '必要な言語スキル': 'JDには記載なし', '必要なテクニカルスキル': 'Experience with machine learning fundamentals; working knowledge of Python; experience with deep learning frameworks such as Pytorch, TensorFlow, JAX or MXNet'}
# {'会社名': 'Dataiku', 'ポジション名': 'Senior Data Scientist', '必要な学歴': 'JDには記載なし', '必要な経験年数': '8 years + of experience in advanced analytics, data science projects, or consulting', '必要な言語スキル': 'Japanese - native; highly proficient in spoken and written English', '必要なテクニカルスキル': 'Over 5 years of experience with Python and SQL; Over 5 years of experience with building ML models and using ML tools (e.g. sklearn)'}

# %%
df = pd.DataFrame({'会社名':l0,
                   'ポジション名':l1,
                   '必要な学歴':l2,
                   '必要な経験年数':l3,
                   '必要な言語スキル':l4,
                   '必要なテクニカルスキル':l5})
df
# Out:
#                             会社名                                     ポジション名  \
# 0                   Digital BCG                             Data Scientist
# 1           Robust Intelligence                  Machine Learning Engineer
# 2               Eli Lilly Japan  Data Scientist – OUS Commercial Analytics
# 3                        OpenAI       Principal Solutions Engineer – Japan
# 4                 Money Forward               AI/Machine Learning Engineer
# 5  Amazon Web Services Japan GK               Sr. Generative AI Specialist
# 6                       Dataiku                      Senior Data Scientist
#
#                                                必要な学歴  \
# 0                 Master's degree in a related field
# 1                                           JDには記載なし
# 2  M.S. or higher in Statistics, Econometrics, Op...
# 3                                           JDには記載なし
# 4                                           JDには記載なし
# 5  Bachelor's degree in computer science or equiv...
# 6                                           JDには記載なし
#
#                                              必要な経験年数  \
# 0      3+ years of work experience in data analytics
# 1  At least three years of professional experienc...
# 2                                           JDには記載なし
# 3  7+ years of experience in a Solutions Engineer...
# 4  Experience in practical application of AI/mach...
# 5            5+ years of relevant working experience
# 6  8 years + of experience in advanced analytics,...
#
#                                             必要な言語スキル  \
# 0  English proficiency (daily conversation level ...
# 1  Native level fluency in spoken and written Jap...
# 2  Business level proficiency in English; Busines...
# 3  Business level proficiency in English; Busines...
# 4  Basic business level English skills (equivalen...
# 5                                           JDには記載なし
# 6  Japanese - native; highly proficient in spoken...
#
#                                          必要なテクニカルスキル
# 0  Coding skills in Python, R; Analysis experienc...
# 1  Knowledge and experience of Python; Familiarit...
# 2  Deep and broad knowledge of statistical modeli...
# 3  Thorough understanding and knowledge of IT sec...
# 4  Experience and understanding of software devel...
# 5  Experience with machine learning fundamentals;...
# 6  Over 5 years of experience with Python and SQL...

# %%
df.to_csv('../outputs/JD_info.csv', index=False)
